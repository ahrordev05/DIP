# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('img.png', cv2.IMREAD_GRAYSCALE)
equilized_image = cv2.equalizeHist(image)
plt.figure(figsize = (10, 5))

plt.subplot(2, 2, 1)
plt.imshow(image, cmap = 'gray')
plt.title('Original Image')
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(599.5), np.float64(349.5), np.float64(-0.5))

# %%
plt.subplot(2, 2, 2)
plt.hist(image.ravel(), bins = 256)
plt.title('Histogram')
plt.axis("off")
# Out:
# (np.float64(-4.25), np.float64(243.25), np.float64(0.0), np.float64(3417.75))

# %%
plt.subplot(2, 2, 3)
plt.imshow(equilized_image, cmap = 'gray')
plt.title('Equalized Image')
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(599.5), np.float64(349.5), np.float64(-0.5))
